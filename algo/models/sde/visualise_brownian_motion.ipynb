# %%
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

from trading.algo.sde.brownian_motion import BrownianMotion


np.random.seed(0)

# %%
bm = BrownianMotion()

dW = bm.dW(num_samples=1000)
W = bm.W(num_samples=1000)

fig = plt.figure(figsize=(15, 5))

title = "Brownian motion increments"
plt.subplot(1, 2, 1)
plt.plot(dW)
plt.gca().set_title(title, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

title = "Brownian motion path"
plt.subplot(1, 2, 2)
plt.plot(W)
plt.gca().set_title(title, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# Out:
# (array([-10.,  -5.,   0.,   5.,  10.,  15.,  20.,  25.,  30.,  35.]),
#  [Text(0, -10.0, '−10'),
#   Text(0, -5.0, '−5'),
#   Text(0, 0.0, '0'),
#   Text(0, 5.0, '5'),
#   Text(0, 10.0, '10'),
#   Text(0, 15.0, '15'),
#   Text(0, 20.0, '20'),
#   Text(0, 25.0, '25'),
#   Text(0, 30.0, '30'),
#   Text(0, 35.0, '35')])
